# %%
# SIMULATIONS NOTEBOOK

# This notebook runs a simulation for the Solar Dynamo model with the sABC algorithm.
# The results of the simulation, as well as the parameters used for the simulated data and 
# the simulation itself are all stored in files in the directory Simulations/Simulations i.
# The reason behind this is to have an easier access to the results of already run simulations,
# without running them again.

# NB: In this notebook, there's no function to visualize the results: the visualization is all
# contained in the "visualization.ipynb" notebook.

# RULES:

# There are two ways to use this notebook:
# 1) change all the parameters and then run all -> correct way
# 2) change things randomly and not in order and then run -> wrong way
# Please be careful, some functions change the directory in which everything is being saved; the
# order of the calling of the functions is organized to start from a generic dir, create the dir
# Simulations/Simulation i, go to that directory and then, when everythingis finished, go back to
# the initial dir!!! If you don't do that, it will stay in the subdir and at the next run it will
# create a subdir of a subdir -> if you need to stop midway through because u forgot something, 
# remember to come back to the initial directory (and eliminate the directory that has not correct
# files inside).

# GG EZ - kallo27

# %%
# NEEDED PACKAGES -> no visualization!!

using DifferentialEquations
using StochasticDelayDiffEq
using SpecialFunctions
using Distributions
using SimulatedAnnealingABC
using Distances
using DataFrames
using FFTW
using CSV

# %%
# FUNCTIONS NEDEED FOR THE MODEL

# Box-shaped function for the magnetic field range 
function f(B, B_max = 10, B_min = 1)
    return 1 / 4 * (1 .+ erf.(B .^ 2 .- B_min ^ 2)) .* (1 .- erf.(B .^ 2 .- B_max ^ 2))
  end
  
  # Model function for the DDE
  function MagneticField(du, u, h, p, t)
    N, T, tau, sigma, Bmax = p
    q = T / tau
  
    B, dB = u
  
    du[1] = dB
    du[2] = - ((2 / tau) * dB + (B / tau^2) + N * h(p, t - q)[1] * f(h(p, t - q)[1], Bmax))
  end
  
  # Noise function for the DDE
  function noise!(du, u, h, p, t)
    N, T, tau, sigma, Bmax = p
    du[1] = (sigma * Bmax)
  end
  
  # Distance function in the sABC algorithm
  function f_dist(θ::Vector{Float64}; type::Int64 = 1, indeces::Vector{Int64}, fourier_data::Vector{Float64})
    prob = SDDEProblem(MagneticField, noise!, B0, h, tspan, θ)
    sol = solve(prob, EM(), dt = 0.01)
    
    simulated_data = sol[1,:]
    fourier_transform = fft(simulated_data)
    fourier_stats = abs.(fourier_transform[indeces])
  
    rho = [euclidean(fourier_stats[i], fourier_data[i]) for i in 1:length(fourier_stats)]
    return rho
  end
  
  # function for the summary statistics
  function reduced_fourier_spectrum(u::Vector{Float64}, indeces::Vector{Int64})
    fourier_transform = fft(u)
    return abs.(fourier_transform[indeces])
  end
# Out:
# reduced_fourier_spectrum (generic function with 1 method)

# %%
# FUNCTIONS NEEDED FOR SAVING THE RESULTS OF A SIMULATION

# function to create a new directory for each simulations, in order to store the needed files
function create_directory()
    base_path = pwd()
    base_path = joinpath(base_path, "Simulations")
    i = 1
    dir_name = "Simulation $i"
    dir_path = joinpath(base_path, dir_name)
    
    while isdir(dir_path)
      i += 1
      dir_name = "Simulation $i"
      dir_path = joinpath(base_path, dir_name)
    end
    
    mkpath(dir_path)
    println("Directory created at: $dir_path")
    cd(dir_path)
  end
  
  # function to save the params of the simulated data
  function write_params_sim(par::Vector{Float64}, tspan::Tuple{Int, Int}, dt::Float64, B0::Vector{Float64}, h0::Vector{Float64}, noise0::Vector{Float64})
    df = DataFrame(
      Parameter = ["N", "T", "tau", "sigma", "B_max", "tspan", "dt", "B0", "h", "noise0"],
      Value = [par[1], par[2], par[3], par[4], par[5], tspan, dt, B0, h0, noise0]
    )
  
    CSV.write("parameters.csv", df)
  end
  
  # function to save the solution of the SDDE for the simulated data
  function save_solution(sol::Union{RODESolution, Vector{RODESolution}})
    curr_path = pwd()
    filename = "simulated_sol.csv"
    path = joinpath(curr_path, filename)
  
    solution_df = DataFrame(Time = sol.t, u = sol[1, :], du = sol[2, :])
    CSV.write(filename, solution_df)
    println("Solution saved to file: $path")
  end
  
  # function to save the prior as a string
  function get_prior_string(prior)
    parts = []
    for d in prior.dists
      if isa(d, Uniform)
        push!(parts, "Uniform($(minimum(d)), $(maximum(d)))")
      else
        error("Unsupported distribution type: $(typeof(d))")
      end
    end
    
    return "product_distribution(" * join(parts, ", ") * ")"
  end
  
  # function to save the sabc parameters
  function save_sabc_params(prior, n_particles::Int, n_simulation::Int, v::Float64, type::Int, indeces::Vector{Int})
    curr_path = pwd()
    filename = "sabc_params.csv"
    path = joinpath(curr_path, filename)
      
    sabc_params = DataFrame(
      Parameter = ["prior", "n_particles", "n_simulation", "v", "type", "indeces"],
      Value = [get_prior_string(prior), n_particles, n_simulation, v, type, string(indeces)]
    )
      
   CSV.write(filename, sabc_params) 
   println("Parameters saved to: $path")
  end
  
  # Function to save the result object of a sABC algorithm
  function save_result(result::SimulatedAnnealingABC.SABCresult{Vector{Float64}, Float64})
    curr_path = pwd()
    filenames = ["eps_hist.csv", "u_hist.csv", "rho_hist.csv"]
    variables = [result.state.ϵ_history, result.state.u_history, result.state.ρ_history]
  
    for (filename, variable) in zip(filenames, variables)
      labels = string.(1:size(variable, 1))
      path = joinpath(curr_path, filename)
      CSV.write(path, DataFrame(variable, labels))
      println("$filename data saved to: $path")
    end
  
    filename = "pop_hist.csv"
    path = joinpath(curr_path, filename)
  
    param_samples = hcat(result.population...)
  
    posterior_params = DataFrame(
      N_value = param_samples[1, :],
      T_value = param_samples[2, :],
      tau_value = param_samples[3, :],
      sigma_value = param_samples[4, :],
      Bmax_value = param_samples[5, :]
    )
  
    CSV.write(path, posterior_params)
    println("Posterior parameters saved to: $path")
  end
# Out:
# save_result (generic function with 1 method)

# %%
# DIRECTORY MANAGING

# Current directory
initial_directory = pwd()

# New directory
create_directory()

# NB: After "create_directory", we move to the new directory.
# DON'T RUN THIS AGAIN, wait for the simulation to finish!!!! If you made errors,
# eliminate the Simulations/Simulation i directory and then rerun everything
# Out:
# Directory created at: c:\Users\lucre\Desktop\physics of data\Project Solar Dynamo\Simulations\Simulation 3

# %%
# SIMULATED DATA PARAMETERS MANAGING

# Parameters for the simulated data
N = 6.2
T = 3.1
tau = 3.5
sigma = 0.04
B_max = 6.0

par = [N, T, tau, sigma, B_max]

# Time
tspan = (0, 1000)
dt = 0.01

# Initial conditions
B0 = [3.0, 0.0]
h0 = [0.0, 0.0]
noise0 = [1.0]

# Writing on file "parameters.csv" of the values set in this cell.
write_params_sim(par, tspan, dt, B0, h0, noise0)
# Out:
# "parameters.csv"

# %%
# DATA SIMULATION

# Data simulation with the chosen parameter
h(p, t) = h0
prob = SDDEProblem(MagneticField, noise!, B0, h, tspan, par)
sol = solve(prob, EM(), dt = dt)

# Important solution data that are necessary afterwards
t = sol.t
u = sol[1, :]
du = sol[2, :]

# Writing of the solution of the SDDE on file "simulated_sol.csv"
save_solution(sol)
# Out:
# Solution saved to file: c:\Users\lucre\Desktop\physics of data\Project Solar Dynamo\Simulations\Simulation 3\simulated_sol.csv

# %%
# SIMULATION PARAMETERS MANAGING

# Parameters that can be tuned for new simulations
prior = product_distribution(Uniform(1, 15), Uniform(0.1, 15.0), Uniform(0.1, 6.0), Uniform(0.01, 0.3), Uniform(1, 15))
n_particles = 1000
n_simulation = 3000000
v = 1.0
type = 1
freqs = [0.29, 0.88, 1.46, 2.05, 2.64, 3.22] 
n = length(u)
indeces = round.(Int, freqs * n / (2π)) .+ 1
# Writing on file "sabc_params.csv" of the values set in this cell.
save_sabc_params(prior, n_particles, n_simulation, v, type, indeces)
# Out:
# Parameters saved to: c:\Users\lucre\Desktop\physics of data\Project Solar Dynamo\Simulations\Simulation 3\sabc_params.csv

# %%
# SIMULATION

# Creation of the summary statistics from the simulated data
sim_ss = reduced_fourier_spectrum(u, indeces)

# Actual usage of the sABC algorithm
result = sabc(f_dist, prior;
              n_particles = n_particles, 
              n_simulation = n_simulation,
              v = v,
              type = type,
              indeces = indeces,
              fourier_data = sim_ss)

# Display of the summary of the results
display(result)

# Saving the results to the files: "eps_hist.csv", "u_hist.csv", "rho_hist.csv", "pop_hist.csv".
save_result(result)
# Out:
# ┌ Info: Using threads: 4
# └ @ SimulatedAnnealingABC C:\Users\lucre\.julia\packages\SimulatedAnnealingABC\LT2t8\src\SimulatedAnnealingABC.jl:192
# ┌ Info: Set BLAS threads = 1
# └ @ SimulatedAnnealingABC C:\Users\lucre\.julia\packages\SimulatedAnnealingABC\LT2t8\src\SimulatedAnnealingABC.jl:195
# ┌ Info: Initializing population...
# └ @ SimulatedAnnealingABC C:\Users\lucre\.julia\packages\SimulatedAnnealingABC\LT2t8\src\SimulatedAnnealingABC.jl:219
# ┌ Info: Initial resampling (δ = 0.1) - ESS = 917.4346894183328
# └ @ SimulatedAnnealingABC C:\Users\lucre\.julia\packages\SimulatedAnnealingABC\LT2t8\src\SimulatedAnnealingABC.jl:258
# ┌ Info: Population with 1000 particles initialised.
# └ @ SimulatedAnnealingABC C:\Users\lucre\.julia\packages\SimulatedAnnealingABC\LT2t8\src\SimulatedAnnealingABC.jl:280
# ┌ Info: Initial ϵ = [1.1025163249014174, 1.1846699187831298, 1.413769045191338, 1.172039518382404, 1.1428378263219685, 1.2487372805437003]
# └ @ SimulatedAnnealingABC C:\Users\lucre\.julia\packages\SimulatedAnnealingABC\LT2t8\src\SimulatedAnnealingABC.jl:281
# ┌ Info: 2024-06-04T11:00:14.425 -- Starting population updates.
# └ @ SimulatedAnnealingABC C:\Users\lucre\.julia\packages\SimulatedAnnealingABC\LT2t8\src\SimulatedAnnealingABC.jl:327
# ┌ Info: Resampling 2 (δ = 0.1) - ESS = 934.1527664390916
# └ @ SimulatedAnnealingABC C:\Users\lucre\.julia\packages\SimulatedAnnealingABC\LT2t8\src\SimulatedAnnealingABC.jl:459
# ┌ Info: 2024-06-04T11:13:27.830 -- Update 100 of 2999 -- ETA: 06:23:20
# │  ϵ: [0.02907, 0.01966, 0.02658, 0.02791, 0.0149, 0.02311]
# │  mean transformed distance: 0.09275
# └ @ SimulatedAnnealingABC C:\Users\lucre\.julia\packages\SimulatedAnnealingABC\LT2t8\src\SimulatedAnnealingABC.jl:472
# ┌ Info: Resampling 3 (δ = 0.1) - ESS = 975.7384254955448
# └ @ SimulatedAnnealingABC C:\Users\lucre\.julia\packages\SimulatedAnnealingABC\LT2t8\src\SimulatedAnnealingABC.jl:459
# ┌ Info: 2024-06-04T11:27:37.006 -- Update 200 of 2999 -- ETA: 06:23:07
# │  ϵ: [0.01441, 0.009442, 0.01342, 0.01482, 0.008235, 0.01115]
# │  mean transformed distance: 0.07569
# └ @ SimulatedAnnealingABC C:\Users\lucre\.julia\packages\SimulatedAnnealingABC\LT2t8\src\SimulatedAnnealingABC.jl:472
# ┌ Info: 2024-06-04T11:41:33.624 -- Update 300 of 2999 -- ETA: 06:11:44
# │  ϵ: [0.01068, 0.00753, 0.009029, 0.01138, 0.007004, 0.00958]
# │  mean transformed distance: 0.07041
# └ @ SimulatedAnnealingABC C:\Users\lucre\.julia\packages\SimulatedAnnealingABC\LT2t8\src\SimulatedAnnealingABC.jl:472
# ┌ Info: 2024-06-04T11:55:19.731 -- Update 400 of 2999 -- ETA: 05:57:56
# │  ϵ: [0.009091, 0.006538, 0.007825, 0.008813, 0.005837, 0.007618]
# │  mean transformed distance: 0.06685
# └ @ SimulatedAnnealingABC C:\Users\lucre\.julia\packages\SimulatedAnnealingABC\LT2t8\src\SimulatedAnnealingABC.jl:472
# ┌ Info: 2024-06-04T12:09:11.437 -- Update 500 of 2999 -- ETA: 05:44:36
# │  ϵ: [0.007551, 0.005219, 0.006941, 0.008543, 0.005017, 0.006105]
# │  mean transformed distance: 0.06414
# └ @ SimulatedAnnealingABC C:\Users\lucre\.julia\packages\SimulatedAnnealingABC\LT2t8\src\SimulatedAnnealingABC.jl:472
# ┌ Info: Resampling 4 (δ = 0.1) - ESS = 983.0434122678748
# └ @ SimulatedAnnealingABC C:\Users\lucre\.julia\packages\SimulatedAnnealingABC\LT2t8\src\SimulatedAnnealingABC.jl:459
# ┌ Info: 2024-06-04T12:23:14.716 -- Update 600 of 2999 -- ETA: 05:31:52
# │  ϵ: [0.00602, 0.004669, 0.006382, 0.006451, 0.003997, 0.004939]
# │  mean transformed distance: 0.0609
# └ @ SimulatedAnnealingABC C:\Users\lucre\.julia\packages\SimulatedAnnealingABC\LT2t8\src\SimulatedAnnealingABC.jl:472
# ┌ Info: 2024-06-04T12:37:25.809 -- Update 700 of 2999 -- ETA: 05:19:11
# │  ϵ: [0.004908, 0.004387, 0.005367, 0.005757, 0.003716, 0.004873]
# │  mean transformed distance: 0.05913
# └ @ SimulatedAnnealingABC C:\Users\lucre\.julia\packages\SimulatedAnnealingABC\LT2t8\src\SimulatedAnnealingABC.jl:472
# ┌ Info: 2024-06-04T12:51:42.299 -- Update 800 of 2999 -- ETA: 05:06:23
# │  ϵ: [0.004493, 0.003975, 0.004566, 0.005546, 0.003777, 0.004458]
# │  mean transformed distance: 0.05792
# └ @ SimulatedAnnealingABC C:\Users\lucre\.julia\packages\SimulatedAnnealingABC\LT2t8\src\SimulatedAnnealingABC.jl:472
# ┌ Info: 2024-06-04T13:06:11.167 -- Update 900 of 2999 -- ETA: 04:53:44
# │  ϵ: [0.004442, 0.004006, 0.004239, 0.005045, 0.003335, 0.004053]
# │  mean transformed distance: 0.05692
# └ @ SimulatedAnnealingABC C:\Users\lucre\.julia\packages\SimulatedAnnealingABC\LT2t8\src\SimulatedAnnealingABC.jl:472
# ┌ Info: 2024-06-04T13:20:33.588 -- Update 1000 of 2999 -- ETA: 04:40:29
# │  ϵ: [0.004184, 0.003667, 0.003743, 0.004536, 0.003227, 0.003967]
# │  mean transformed distance: 0.05583
# └ @ SimulatedAnnealingABC C:\Users\lucre\.julia\packages\SimulatedAnnealingABC\LT2t8\src\SimulatedAnnealingABC.jl:472
# ┌ Info: 2024-06-04T13:35:09.294 -- Update 1100 of 2999 -- ETA: 04:27:26
# │  ϵ: [0.003811, 0.003195, 0.003618, 0.004469, 0.003011, 0.00354]
# │  mean transformed distance: 0.05472
# └ @ SimulatedAnnealingABC C:\Users\lucre\.julia\packages\SimulatedAnnealingABC\LT2t8\src\SimulatedAnnealingABC.jl:472
# ┌ Info: 2024-06-04T13:49:42.298 -- Update 1200 of 2999 -- ETA: 04:14:03
# │  ϵ: [0.003726, 0.003186, 0.003616, 0.003712, 0.002891, 0.003318]
# │  mean transformed distance: 0.05394
# └ @ SimulatedAnnealingABC C:\Users\lucre\.julia\packages\SimulatedAnnealingABC\LT2t8\src\SimulatedAnnealingABC.jl:472
# ┌ Info: 2024-06-04T14:04:18.314 -- Update 1300 of 2999 -- ETA: 04:00:33
# │  ϵ: [0.003539, 0.002823, 0.003221, 0.003814, 0.002795, 0.003199]
# │  mean transformed distance: 0.05318
# └ @ SimulatedAnnealingABC C:\Users\lucre\.julia\packages\SimulatedAnnealingABC\LT2t8\src\SimulatedAnnealingABC.jl:472
# ┌ Info: 2024-06-04T14:19:09.599 -- Update 1400 of 2999 -- ETA: 03:47:11
# │  ϵ: [0.003318, 0.002685, 0.003026, 0.003704, 0.002579, 0.003029]
# │  mean transformed distance: 0.0524
# └ @ SimulatedAnnealingABC C:\Users\lucre\.julia\packages\SimulatedAnnealingABC\LT2t8\src\SimulatedAnnealingABC.jl:472
# ┌ Info: 2024-06-04T14:34:10.208 -- Update 1500 of 2999 -- ETA: 03:33:47
# │  ϵ: [0.003065, 0.002575, 0.003083, 0.003424, 0.002498, 0.002899]
# │  mean transformed distance: 0.05181
# └ @ SimulatedAnnealingABC C:\Users\lucre\.julia\packages\SimulatedAnnealingABC\LT2t8\src\SimulatedAnnealingABC.jl:472
# ┌ Info: 2024-06-04T14:48:56.637 -- Update 1600 of 2999 -- ETA: 03:19:58
# │  ϵ: [0.002979, 0.00253, 0.003001, 0.003271, 0.002356, 0.002723]
# │  mean transformed distance: 0.05127
# └ @ SimulatedAnnealingABC C:\Users\lucre\.julia\packages\SimulatedAnnealingABC\LT2t8\src\SimulatedAnnealingABC.jl:472
# ┌ Info: 2024-06-04T15:03:47.498 -- Update 1700 of 2999 -- ETA: 03:06:06
# │  ϵ: [0.002826, 0.002433, 0.002811, 0.003112, 0.002344, 0.002586]
# │  mean transformed distance: 0.05068
# └ @ SimulatedAnnealingABC C:\Users\lucre\.julia\packages\SimulatedAnnealingABC\LT2t8\src\SimulatedAnnealingABC.jl:472
# ┌ Info: 2024-06-04T15:23:21.180 -- Update 1800 of 2999 -- ETA: 02:55:15
# │  ϵ: [0.002894, 0.002273, 0.002692, 0.003309, 0.002026, 0.002348]
# │  mean transformed distance: 0.05015
# └ @ SimulatedAnnealingABC C:\Users\lucre\.julia\packages\SimulatedAnnealingABC\LT2t8\src\SimulatedAnnealingABC.jl:472
# ┌ Info: 2024-06-04T15:39:35.553 -- Update 1900 of 2999 -- ETA: 02:41:34
# │  ϵ: [0.002692, 0.002289, 0.002687, 0.003056, 0.001974, 0.002315]
# │  mean transformed distance: 0.04972
# └ @ SimulatedAnnealingABC C:\Users\lucre\.julia\packages\SimulatedAnnealingABC\LT2t8\src\SimulatedAnnealingABC.jl:472
# ┌ Info: 2024-06-04T15:57:05.555 -- Update 2000 of 2999 -- ETA: 02:28:16
# │  ϵ: [0.002633, 0.002066, 0.002579, 0.002954, 0.002021, 0.002152]
# │  mean transformed distance: 0.04919
# └ @ SimulatedAnnealingABC C:\Users\lucre\.julia\packages\SimulatedAnnealingABC\LT2t8\src\SimulatedAnnealingABC.jl:472
# ┌ Info: 2024-06-04T16:12:38.345 -- Update 2100 of 2999 -- ETA: 02:13:44
# │  ϵ: [0.002556, 0.002115, 0.002425, 0.002826, 0.001947, 0.002156]
# │  mean transformed distance: 0.04886
# └ @ SimulatedAnnealingABC C:\Users\lucre\.julia\packages\SimulatedAnnealingABC\LT2t8\src\SimulatedAnnealingABC.jl:472
# ┌ Info: 2024-06-04T16:28:19.674 -- Update 2200 of 2999 -- ETA: 01:59:09
# │  ϵ: [0.002459, 0.002162, 0.002234, 0.002859, 0.001893, 0.00206]
# │  mean transformed distance: 0.04853
# └ @ SimulatedAnnealingABC C:\Users\lucre\.julia\packages\SimulatedAnnealingABC\LT2t8\src\SimulatedAnnealingABC.jl:472
# ┌ Info: 2024-06-04T16:43:59.212 -- Update 2300 of 2999 -- ETA: 01:44:28
# │  ϵ: [0.002411, 0.002033, 0.002294, 0.002821, 0.001794, 0.001929]
# │  mean transformed distance: 0.04816
# └ @ SimulatedAnnealingABC C:\Users\lucre\.julia\packages\SimulatedAnnealingABC\LT2t8\src\SimulatedAnnealingABC.jl:472
# ┌ Info: 2024-06-04T16:59:56.852 -- Update 2400 of 2999 -- ETA: 01:29:46
# │  ϵ: [0.002382, 0.001907, 0.002275, 0.00258, 0.001846, 0.001829]
# │  mean transformed distance: 0.04773
# └ @ SimulatedAnnealingABC C:\Users\lucre\.julia\packages\SimulatedAnnealingABC\LT2t8\src\SimulatedAnnealingABC.jl:472
# ┌ Info: 2024-06-04T17:15:42.168 -- Update 2500 of 2999 -- ETA: 01:14:56
# │  ϵ: [0.002276, 0.001934, 0.002073, 0.002608, 0.001766, 0.001845]
# │  mean transformed distance: 0.04742
# └ @ SimulatedAnnealingABC C:\Users\lucre\.julia\packages\SimulatedAnnealingABC\LT2t8\src\SimulatedAnnealingABC.jl:472
# ┌ Info: 2024-06-04T17:31:17.477 -- Update 2600 of 2999 -- ETA: 01:00:00
# │  ϵ: [0.002107, 0.001904, 0.002015, 0.00261, 0.001724, 0.001807]
# │  mean transformed distance: 0.04709
# └ @ SimulatedAnnealingABC C:\Users\lucre\.julia\packages\SimulatedAnnealingABC\LT2t8\src\SimulatedAnnealingABC.jl:472
# ┌ Info: 2024-06-04T17:46:55.277 -- Update 2700 of 2999 -- ETA: 00:45:02
# │  ϵ: [0.002102, 0.001886, 0.001935, 0.002459, 0.001726, 0.001793]
# │  mean transformed distance: 0.04683
# └ @ SimulatedAnnealingABC C:\Users\lucre\.julia\packages\SimulatedAnnealingABC\LT2t8\src\SimulatedAnnealingABC.jl:472
# ┌ Info: 2024-06-04T18:02:30.729 -- Update 2800 of 2999 -- ETA: 00:30:00
# │  ϵ: [0.001992, 0.001792, 0.002065, 0.002544, 0.001596, 0.001693]
# │  mean transformed distance: 0.04658
# └ @ SimulatedAnnealingABC C:\Users\lucre\.julia\packages\SimulatedAnnealingABC\LT2t8\src\SimulatedAnnealingABC.jl:472
# ┌ Info: 2024-06-04T18:18:06.337 -- Update 2900 of 2999 -- ETA: 00:14:56
# │  ϵ: [0.001882, 0.001786, 0.001892, 0.002455, 0.00151, 0.001803]
# │  mean transformed distance: 0.04622
# └ @ SimulatedAnnealingABC C:\Users\lucre\.julia\packages\SimulatedAnnealingABC\LT2t8\src\SimulatedAnnealingABC.jl:472
# ┌ Info: 2024-06-04T18:33:33.661  All particles have been updated 2999 times.
# └ @ SimulatedAnnealingABC C:\Users\lucre\.julia\packages\SimulatedAnnealingABC\LT2t8\src\SimulatedAnnealingABC.jl:506
# Approximate posterior sample with 1000 particles:
#   - simulations used: 3000000
#   - average transformed distance: 0.04595
#   - ϵ: [0.001737, 0.001799, 0.001859, 0.002334, 0.001499, 0.001832]
#   - population resampling: 4
#   - acceptance rate: 0.00331
# The sample can be accessed with the field `population`.
# The history of ϵ can be accessed with the field `state.ϵ_history`.
#  --------------------------------------
# eps_hist.csv data saved to: c:\Users\lucre\Desktop\physics of data\Project Solar Dynamo\Simulations\Simulation 3\eps_hist.csv
# u_hist.csv data saved to: c:\Users\lucre\Desktop\physics of data\Project Solar Dynamo\Simulations\Simulation 3\u_hist.csv
# rho_hist.csv data saved to: c:\Users\lucre\Desktop\physics of data\Project Solar Dynamo\Simulations\Simulation 3\rho_hist.csv
# Posterior parameters saved to: c:\Users\lucre\Desktop\physics of data\Project Solar Dynamo\Simulations\Simulation 3\pop_hist.csv

# %%
# DIRECTORY MANAGING

# WE go back to the initial directory
cd(initial_directory)
pwd()
# Out:
# "c:\\Users\\lucre\\Desktop\\physics of data\\Project Solar Dynamo"
