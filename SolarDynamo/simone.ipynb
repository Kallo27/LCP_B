# %%
# NEEDED PACKAGES -> no visualization!!

using StochasticDelayDiffEq
using SpecialFunctions
using Distributions
using SimulatedAnnealingABC
using Distances
using DataFrames
using FFTW
using CSV
using XLSX
using ThreadPinning

# %%
include("./SDDESolarDynamo.jl")
using .SDDESolarDynamo

# %%
# Distance function in the sABC algorithm
function f_dist(θ::Vector{Float64}; type::Int64 = 1, indices::Union{Vector{Int64}, StepRange{Int64, Int64}} = 1:6:120, fourier_data::Vector{Float64})
  sol = bfield(θ, Tsim)
  
  simulated_data = sol[1,:]
  simulated_data = simulated_data .^ 2
  fourier_stats = reduced_fourier_spectrum(simulated_data, indices)

  rho = [euclidean(fourier_stats[i], fourier_data[i]) for i in 1:length(fourier_stats)]
  return rho
end

# function for the summary statistics
function reduced_fourier_spectrum(u::Vector{Float64}, indices::Union{Vector{Int64}, StepRange{Int64, Int64}} = 1:6:120)
  fourier_transform = abs.(fft(u))
  return fourier_transform[indices]
end
# Out:
# reduced_fourier_spectrum (generic function with 2 methods)

# %%
# FUNCTIONS NEEDED FOR SAVING THE RESULTS OF A SIMULATION

# function to create a new directory for each simulations, in order to store the needed files
function create_directory()
  base_path = pwd()
  base_path = joinpath(base_path, "Simulations")
  i = 1
  dir_name = "Real $i"
  dir_path = joinpath(base_path, dir_name)
  
  while isdir(dir_path)
    i += 1
    dir_name = "Real $i"
    dir_path = joinpath(base_path, dir_name)
  end
  
  mkpath(dir_path)
  println("Directory created at: $dir_path")
  cd(dir_path)
end

# function to save the prior as a string
function get_prior_string(prior)
  parts = []
  for d in prior.dists
    if isa(d, Uniform)
      push!(parts, "Uniform($(minimum(d)), $(maximum(d)))")
    else
      error("Unsupported distribution type: $(typeof(d))")
    end
  end
  
  return "product_distribution(" * join(parts, ", ") * ")"
end

# function to save the sabc parameters
function save_sabc_params(prior, n_particles::Int, n_simulation::Int, v::Float64, type::Int, indices::Union{Vector{Int}, StepRange{Int64, Int64}})
  curr_path = pwd()
  filename = "sabc_params.csv"
  path = joinpath(curr_path, filename)
    
  sabc_params = DataFrame(
    Parameter = ["prior", "n_particles", "n_simulation", "v", "type", "indices"],
    Value = [get_prior_string(prior), n_particles, n_simulation, v, type, string(indices)]
  )
    
 CSV.write(filename, sabc_params) 
 println("Parameters saved to: $path")
end

# Function to save the result object of a sABC algorithm
function save_result(result::SimulatedAnnealingABC.SABCresult{Vector{Float64}, Float64})
  curr_path = pwd()
  filenames = ["eps_hist.csv", "u_hist.csv", "rho_hist.csv"]
  variables = [result.state.ϵ_history, result.state.u_history, result.state.ρ_history]

  for (filename, variable) in zip(filenames, variables)
    labels = string.(1:size(variable, 1))
    path = joinpath(curr_path, filename)
    CSV.write(path, DataFrame(variable, labels))
    println("$filename data saved to: $path")
  end

  filename = "pop.csv"
  path = joinpath(curr_path, filename)

  param_samples = hcat(result.population...)

  posterior_params = DataFrame(
    N_value = param_samples[1, :],
    T_value = param_samples[2, :],
    tau_value = param_samples[3, :],
    sigma_value = param_samples[4, :],
    Bmax_value = param_samples[5, :]
  )

  CSV.write(path, posterior_params)
  println("Posterior parameters saved to: $path")

  filename = "rho.csv"
  path = joinpath(curr_path, filename)

  rho = result.ρ

  rho_values = DataFrame(rho, [:ss1, :ss2, :ss3, :ss4, :ss5, :ss6])

  CSV.write(path, rho_values)
  println("Rho values saved to: $path")
end
# Out:
# save_result (generic function with 1 method)

# %%
# THREADS SETTINGS AND INFO

ThreadPinning.pinthreads(:cores)
ThreadPinning.threadinfo()
# Out:
# System: 8 cores (no SMT), 8 sockets, 1 NUMA domains
#
# | 0 | 1 | 2 | 3 | 4 | 5 | 6 | 7 |
#
# # = Julia thread, | = Socket seperator
#
# Julia threads: 8
# ├ Occupied CPU-threads: 8
# └ Mapping (Thread => CPUID): 1 => 0, 2 => 1, 3 => 2, 4 => 3, 5 => 4, ...

# %%
# EXTRACTING OPEN MAGNETIC FLUX AND SUNSPOT NUMBER RECORDS FROM XLSX FILE

# Define DataFrame object
data = DataFrame(
  year = Int[],
  open_magn_flux = Float64[],
  open_magn_flux_err = Float64[],
  ssa_open_magn_flux = Float64[],
  sunspots_num = Float64[],
  sunspots_err = Float64[],
  ssa_sunspots = Float64[]
)

# Open file and for each row write data into the DataFrame
XLSX.openxlsx("SN Usoskin Brehm.xlsx") do file
  sheet = file["Data"] 

  for row in XLSX.eachrow(sheet)
    if isa(row[2], Number)
      push!(data, (
        year = row[2],
        open_magn_flux = row[3],
        open_magn_flux_err = row[4],
        ssa_open_magn_flux = row[5],
        sunspots_num = row[7],
        sunspots_err = row[8],
        ssa_sunspots = row[9]
      ))
    end
  end
end

# Creation of the summary statistics for the real data
u = data.open_magn_flux
indices = [37, 50, 78, 85, 91, 98]

sim_ss = reduced_fourier_spectrum(u, indices)
# Out:
# 6-element Vector{Float64}:
#  121.8823872718697
#  128.89216890856196
#  207.56096406106235
#  274.8631648867697
#   90.49534463044569
#  118.23063548090272

# %%
# DIRECTORY MANAGING

# Current directory
initial_directory = pwd()

# New directory
create_directory()

# NB: After "create_directory", we move to the new directory.
# DON'T RUN THIS AGAIN, wait for the simulation to finish!!!! If you made errors,
# eliminate the Simulations/Simulation i directory and then rerun everything
# Out:
# Directory created at: /home/ubuntu/LCP_B/Project/Simulations/Real 14

# %%
# SIMULATION PARAMETERS MANAGING

# Parameters that can be tuned for new simulations
prior = product_distribution(Uniform(5, 15), Uniform(0.1, 10.0), Uniform(0.1, 6.0), Uniform(0.01, 0.3), Uniform(1, 15))
n_particles = 1000
n_simulation = 5000000
v = 1.0
type = 1

# Writing on file "sabc_params.csv" of the values set in this cell.
save_sabc_params(prior, n_particles, n_simulation, v, type, indices)
# Out:
# Parameters saved to: /home/ubuntu/LCP_B/Project/Simulations/Real 14/sabc_params.csv

# %%
# SIMULATION

# Conditions
tmin = data.year[1]; tmax = data.year[end]
Tsim = tmax - tmin

# Actual usage of the sABC algorithm
result = sabc(f_dist, prior;
              n_particles = n_particles, 
              n_simulation = n_simulation,
              v = v,
              type = type,
              indices = indices,
              fourier_data = sim_ss)

# Display of the summary of the results
display(result)

# Saving the results to the files: "eps_hist.csv", "u_hist.csv", "rho_hist.csv", "pop.csv", "rho.csv".
save_result(result)
# Out:
# ┌ Info: Preparing to run SABC algorithm: 'single-epsilon'
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:188
# ┌ Info: Using threads: 8
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:199
# ┌ Info: Set BLAS threads = 1
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:202
# ┌ Info: Set 'pinthreads(:cores)' for optimal multi-threading performance
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:204
# ┌ Info: Initializing population...
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:223
# ┌ Info: Initial resampling (δ = 0.1) - ESS = 996.6799495718246
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:277
# ┌ Info: Population with 1000 particles initialised.
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:309
# ┌ Info: Initial ϵ = [0.2911077810109295]
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:310
# ┌ Info: 2024-07-20T11:27:40.037 -- Starting population updates.
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:358
# ┌ Info: Resampling 2 (δ = 0.1) - ESS = 992.4340719328545
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:470
# ┌ Info: Resampling 3 (δ = 0.1) - ESS = 991.438657264666
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:470
# ┌ Info: Resampling 4 (δ = 0.1) - ESS = 990.6992153214662
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:470
# ┌ Info: Resampling 5 (δ = 0.1) - ESS = 992.1830089480217
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:470
# ┌ Info: Resampling 6 (δ = 0.1) - ESS = 991.5305536030714
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:470
# ┌ Info: 2024-07-20T11:29:21.861 -- Update 100 of 4999 -- ETA: 01:23:08
# │  ϵ: [0.003356]
# │  mean transformed distance: 0.01434
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:484
# ┌ Info: Resampling 7 (δ = 0.1) - ESS = 992.3486306227996
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:470
# ┌ Info: Resampling 8 (δ = 0.1) - ESS = 990.6609733081389
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:470
# ┌ Info: 2024-07-20T11:31:02.371 -- Update 200 of 4999 -- ETA: 01:20:55
# │  ϵ: [0.0007318]
# │  mean transformed distance: 0.004509
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:484
# ┌ Info: Resampling 9 (δ = 0.1) - ESS = 990.9089948467235
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:470
# ┌ Info: 2024-07-20T11:32:48.653 -- Update 300 of 4999 -- ETA: 01:20:33
# │  ϵ: [0.0003592]
# │  mean transformed distance: 0.002634
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:484
# ┌ Info: 2024-07-20T11:34:37.033 -- Update 400 of 4999 -- ETA: 01:19:54
# │  ϵ: [0.0002614]
# │  mean transformed distance: 0.002072
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:484
# ┌ Info: 2024-07-20T11:36:46.122 -- Update 500 of 4999 -- ETA: 01:21:53
# │  ϵ: [0.0002096]
# │  mean transformed distance: 0.001755
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:484
# ┌ Info: Resampling 10 (δ = 0.1) - ESS = 990.0625118955003
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:470
# ┌ Info: 2024-07-20T11:39:02.565 -- Update 600 of 4999 -- ETA: 01:23:24
# │  ϵ: [0.0001425]
# │  mean transformed distance: 0.001312
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:484
# ┌ Info: 2024-07-20T11:41:19.210 -- Update 700 of 4999 -- ETA: 01:23:50
# │  ϵ: [0.0001218]
# │  mean transformed distance: 0.001166
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:484
# ┌ Info: 2024-07-20T11:43:37.397 -- Update 800 of 4999 -- ETA: 01:23:44
# │  ϵ: [0.0001059]
# │  mean transformed distance: 0.001049
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:484
# ┌ Info: 2024-07-20T11:45:59.811 -- Update 900 of 4999 -- ETA: 01:23:28
# │  ϵ: [9.35e-5]
# │  mean transformed distance: 0.0009554
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:484
# ┌ Info: 2024-07-20T11:48:23.521 -- Update 1000 of 4999 -- ETA: 01:22:52
# │  ϵ: [8.309e-5]
# │  mean transformed distance: 0.0008743
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:484
# ┌ Info: 2024-07-20T11:50:50.390 -- Update 1100 of 4999 -- ETA: 01:22:08
# │  ϵ: [7.681e-5]
# │  mean transformed distance: 0.0008241
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:484
# ┌ Info: 2024-07-20T11:53:16.939 -- Update 1200 of 4999 -- ETA: 01:21:05
# │  ϵ: [6.966e-5]
# │  mean transformed distance: 0.0007657
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:484
# ┌ Info: Resampling 11 (δ = 0.1) - ESS = 989.5138595583223
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:470
# ┌ Info: 2024-07-20T11:55:44.013 -- Update 1300 of 4999 -- ETA: 01:19:51
# │  ϵ: [4.974e-5]
# │  mean transformed distance: 0.0005943
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:484
# ┌ Info: 2024-07-20T11:58:11.153 -- Update 1400 of 4999 -- ETA: 01:18:27
# │  ϵ: [4.755e-5]
# │  mean transformed distance: 0.0005746
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:484
# ┌ Info: 2024-07-20T12:00:39.040 -- Update 1500 of 4999 -- ETA: 01:16:56
# │  ϵ: [4.506e-5]
# │  mean transformed distance: 0.0005518
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:484
# ┌ Info: 2024-07-20T12:03:06.476 -- Update 1600 of 4999 -- ETA: 01:15:17
# │  ϵ: [4.342e-5]
# │  mean transformed distance: 0.0005366
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:484
# ┌ Info: 2024-07-20T12:05:37.392 -- Update 1700 of 4999 -- ETA: 01:13:39
# │  ϵ: [4.183e-5]
# │  mean transformed distance: 0.0005219
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:484
# ┌ Info: 2024-07-20T12:08:11.192 -- Update 1800 of 4999 -- ETA: 01:12:00
# │  ϵ: [4.02e-5]
# │  mean transformed distance: 0.0005064
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:484
# ┌ Info: 2024-07-20T12:10:45.770 -- Update 1900 of 4999 -- ETA: 01:10:17
# │  ϵ: [3.857e-5]
# │  mean transformed distance: 0.000491
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:484
# ┌ Info: 2024-07-20T12:13:18.740 -- Update 2000 of 4999 -- ETA: 01:08:26
# │  ϵ: [3.74e-5]
# │  mean transformed distance: 0.0004797
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:484
# ┌ Info: 2024-07-20T12:15:49.478 -- Update 2100 of 4999 -- ETA: 01:06:28
# │  ϵ: [3.6e-5]
# │  mean transformed distance: 0.0004661
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:484
# ┌ Info: 2024-07-20T12:18:16.421 -- Update 2200 of 4999 -- ETA: 01:04:23
# │  ϵ: [3.499e-5]
# │  mean transformed distance: 0.0004563
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:484
# ┌ Info: 2024-07-20T12:20:44.442 -- Update 2300 of 4999 -- ETA: 01:02:16
# │  ϵ: [3.44e-5]
# │  mean transformed distance: 0.0004505
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:484
# ┌ Info: 2024-07-20T12:23:17.028 -- Update 2400 of 4999 -- ETA: 01:00:13
# │  ϵ: [3.383e-5]
# │  mean transformed distance: 0.0004449
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:484
# ┌ Info: 2024-07-20T12:25:48.759 -- Update 2500 of 4999 -- ETA: 00:58:07
# │  ϵ: [3.318e-5]
# │  mean transformed distance: 0.0004384
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:484
# ┌ Info: 2024-07-20T12:28:19.616 -- Update 2600 of 4999 -- ETA: 00:55:58
# │  ϵ: [3.281e-5]
# │  mean transformed distance: 0.0004347
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:484
# ┌ Info: 2024-07-20T12:30:46.799 -- Update 2700 of 4999 -- ETA: 00:53:44
# │  ϵ: [3.231e-5]
# │  mean transformed distance: 0.0004297
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:484
# ┌ Info: 2024-07-20T12:33:14.384 -- Update 2800 of 4999 -- ETA: 00:51:29
# │  ϵ: [3.208e-5]
# │  mean transformed distance: 0.0004274
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:484
# ┌ Info: Resampling 12 (δ = 0.1) - ESS = 995.4778809069504
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:470
# ┌ Info: 2024-07-20T12:35:43.363 -- Update 2900 of 4999 -- ETA: 00:49:15
# │  ϵ: [2.732e-5]
# │  mean transformed distance: 0.0003789
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:484
# ┌ Info: 2024-07-20T12:38:17.053 -- Update 3000 of 4999 -- ETA: 00:47:03
# │  ϵ: [2.698e-5]
# │  mean transformed distance: 0.0003753
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:484
# ┌ Info: 2024-07-20T12:40:50.349 -- Update 3100 of 4999 -- ETA: 00:44:49
# │  ϵ: [2.66e-5]
# │  mean transformed distance: 0.0003713
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:484
# ┌ Info: 2024-07-20T12:43:23.850 -- Update 3200 of 4999 -- ETA: 00:42:34
# │  ϵ: [2.596e-5]
# │  mean transformed distance: 0.0003646
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:484
# ┌ Info: 2024-07-20T12:45:58.415 -- Update 3300 of 4999 -- ETA: 00:40:18
# │  ϵ: [2.578e-5]
# │  mean transformed distance: 0.0003628
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:484
# ┌ Info: 2024-07-20T12:48:35.211 -- Update 3400 of 4999 -- ETA: 00:38:03
# │  ϵ: [2.545e-5]
# │  mean transformed distance: 0.0003592
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:484
# ┌ Info: 2024-07-20T12:51:04.298 -- Update 3500 of 4999 -- ETA: 00:35:43
# │  ϵ: [2.514e-5]
# │  mean transformed distance: 0.000356
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:484
# ┌ Info: 2024-07-20T12:53:32.848 -- Update 3600 of 4999 -- ETA: 00:33:22
# │  ϵ: [2.488e-5]
# │  mean transformed distance: 0.0003531
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:484
# ┌ Info: 2024-07-20T12:55:59.165 -- Update 3700 of 4999 -- ETA: 00:31:00
# │  ϵ: [2.461e-5]
# │  mean transformed distance: 0.0003502
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:484
# ┌ Info: 2024-07-20T12:58:24.694 -- Update 3800 of 4999 -- ETA: 00:28:37
# │  ϵ: [2.439e-5]
# │  mean transformed distance: 0.0003479
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:484
# ┌ Info: 2024-07-20T13:00:45.335 -- Update 3900 of 4999 -- ETA: 00:26:13
# │  ϵ: [2.419e-5]
# │  mean transformed distance: 0.0003458
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:484
# ┌ Info: 2024-07-20T13:03:14.346 -- Update 4000 of 4999 -- ETA: 00:23:52
# │  ϵ: [2.409e-5]
# │  mean transformed distance: 0.0003447
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:484
# ┌ Info: 2024-07-20T13:05:40.967 -- Update 4100 of 4999 -- ETA: 00:21:29
# │  ϵ: [2.38e-5]
# │  mean transformed distance: 0.0003416
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:484
# ┌ Info: 2024-07-20T13:07:59.510 -- Update 4200 of 4999 -- ETA: 00:19:05
# │  ϵ: [2.358e-5]
# │  mean transformed distance: 0.0003392
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:484
# ┌ Info: 2024-07-20T13:10:26.877 -- Update 4300 of 4999 -- ETA: 00:16:42
# │  ϵ: [2.345e-5]
# │  mean transformed distance: 0.0003378
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:484
# ┌ Info: 2024-07-20T13:12:56.878 -- Update 4400 of 4999 -- ETA: 00:14:19
# │  ϵ: [2.334e-5]
# │  mean transformed distance: 0.0003366
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:484
# ┌ Info: 2024-07-20T13:15:26.994 -- Update 4500 of 4999 -- ETA: 00:11:57
# │  ϵ: [2.323e-5]
# │  mean transformed distance: 0.0003355
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:484
# ┌ Info: 2024-07-20T13:17:47.472 -- Update 4600 of 4999 -- ETA: 00:09:33
# │  ϵ: [2.302e-5]
# │  mean transformed distance: 0.0003331
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:484
# ┌ Info: 2024-07-20T13:20:07.521 -- Update 4700 of 4999 -- ETA: 00:07:09
# │  ϵ: [2.286e-5]
# │  mean transformed distance: 0.0003314
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:484
# ┌ Info: 2024-07-20T13:22:36.631 -- Update 4800 of 4999 -- ETA: 00:04:45
# │  ϵ: [2.268e-5]
# │  mean transformed distance: 0.0003295
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:484
# ┌ Info: 2024-07-20T13:25:15.142 -- Update 4900 of 4999 -- ETA: 00:02:22
# │  ϵ: [2.256e-5]
# │  mean transformed distance: 0.0003282
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:484
# ┌ Info: 2024-07-20T13:27:48.584  All particles have been updated 4999 times.
# └ @ SimulatedAnnealingABC /home/ubuntu/.julia/packages/SimulatedAnnealingABC/e8QsC/src/SimulatedAnnealingABC.jl:518
# Approximate posterior sample with 1000 particles:
#   - simulations used: 5000000
#   - average transformed distance: 0.0003267
#   - ϵ: [2.243e-5]
#   - population resampling: 12
#   - acceptance rate: 0.005077
# The sample can be accessed with the field `population`.
# The history of ϵ can be accessed with the field `state.ϵ_history`.
#  --------------------------------------
# eps_hist.csv data saved to: /home/ubuntu/LCP_B/Project/Simulations/Real 14/eps_hist.csv
# u_hist.csv data saved to: /home/ubuntu/LCP_B/Project/Simulations/Real 14/u_hist.csv
# rho_hist.csv data saved to: /home/ubuntu/LCP_B/Project/Simulations/Real 14/rho_hist.csv
# Posterior parameters saved to: /home/ubuntu/LCP_B/Project/Simulations/Real 14/pop.csv
# Rho values saved to: /home/ubuntu/LCP_B/Project/Simulations/Real 14/rho.csv

# %%
# DIRECTORY MANAGING

# WE go back to the initial directory
cd(initial_directory)
pwd()
# Out:
# "/home/ubuntu/LCP_B/Project"

# %%
rho = result.ρ
df = DataFrame(rho, :auto)

df_squared = DataFrame()

# Iterate over each column and compute the square of each element
for col in names(df)
    df_squared[!, col] = df[!, col] .^ 2
end

# %%
row_sums = Vector{Float64}(undef, size(df, 1))

# Compute the sum of each row and store it in `row_sums`
for (i, row) in enumerate(eachrow(df_squared))
    row_sums[i] = sum(row)
end

# Now `row_sums` contains the sum of each row
k = 5  # Number of minimum values you want to find
new_indices = partialsortperm(row_sums, 1:k)  # Indices of the 5 smallest values
min_values = row_sums[new_indices]  # The 5 smallest values

println("Minimum values: ", min_values)
println("Indices of minimum values: ", new_indices)

param_samples = hcat(result.population...)

posterior_params = DataFrame(
  N_value = param_samples[1, :],
  T_value = param_samples[2, :],
  tau_value = param_samples[3, :],
  sigma_value = param_samples[4, :],
  Bmax_value = param_samples[5, :]
)

best_particles = posterior_params[new_indices, :]
# Out:
# Minimum values: [0.00411135427052349, 0.006256088414023919, 0.006842568256186171, 0.007328675434512834, 0.007389896547476963]
# Indices of minimum values: [794, 173, 772, 728, 419]
# 5×5 DataFrame
#  Row │ N_value  T_value   tau_value  sigma_value  Bmax_value
#      │ Float64  Float64   Float64    Float64      Float64
# ─────┼───────────────────────────────────────────────────────
#    1 │ 5.24506  5.16562     2.74003    0.0881197     7.04645
#    2 │ 7.23879  0.477932    3.02556    0.228607      8.17291
#    3 │ 6.28401  4.64854     3.20052    0.130862      7.79237
#    4 │ 8.1992   4.8252      4.15772    0.0198671     7.15163
#    5 │ 6.75569  4.22528     3.51138    0.271377      7.28355
